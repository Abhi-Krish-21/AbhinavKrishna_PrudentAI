# %% [markdown]
# IMPORT PACAKGES & LOAD DATA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_excel(r"C:\\Users\morch\Downloads\books.xlsx")
df
# Out:
#        bookID                                              title  \
# 0           1  Harry Potter and the Half-Blood Prince (Harry ...
# 1           2  Harry Potter and the Order of the Phoenix (Har...
# 2           4  Harry Potter and the Chamber of Secrets (Harry...
# 3           5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4           8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
# ...       ...                                                ...
# 11122   45631   Expelled from Eden: A William T. Vollmann Reader
# 11123   45633                        You Bright and Risen Angels
# 11124   45634                    The Ice-Shirt (Seven Dreams #1)
# 11125   45639                                        Poor People
# 11126   45641                        Las aventuras de Tom Sawyer
#
#                                                  authors average_rating  \
# 0                            J.K. Rowling/Mary GrandPrÌ©           4.57
# ...

# %% [markdown]
# UNDERSTANDING DATA STRUCTURE & DATA CLEANING

# %%
df.describe()
# Out:
#              bookID  ratings_count  text_reviews_count
# count  11127.000000   1.112700e+04        11127.000000
# mean   21310.938887   1.793647e+04          541.859531
# std    13093.358023   1.124794e+05         2576.175586
# min        1.000000   0.000000e+00            0.000000
# 25%    10287.000000   1.040000e+02            9.000000
# 50%    20287.000000   7.450000e+02           46.000000
# 75%    32104.500000   4.993500e+03          237.500000
# max    45641.000000   4.597666e+06        94265.000000

# %%
df.isnull().sum( )
# Out:
# bookID                    0
# title                     0
# authors                   0
# average_rating            0
# isbn                      0
# isbn13                    0
# language_code             0
# num_pages                 0
# ratings_count             0
# text_reviews_count        0
# publication_date          0
# publisher                 0
# Unnamed: 12           11124
# dtype: int64

# %%
df.drop(["Unnamed: 12"],axis=1,inplace=True)

# %%
df
# Out:
#        bookID                                              title  \
# 0           1  Harry Potter and the Half-Blood Prince (Harry ...
# 1           2  Harry Potter and the Order of the Phoenix (Har...
# 2           4  Harry Potter and the Chamber of Secrets (Harry...
# 3           5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4           8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
# ...       ...                                                ...
# 11122   45631   Expelled from Eden: A William T. Vollmann Reader
# 11123   45633                        You Bright and Risen Angels
# 11124   45634                    The Ice-Shirt (Seven Dreams #1)
# 11125   45639                                        Poor People
# 11126   45641                        Las aventuras de Tom Sawyer
#
#                                                  authors average_rating  \
# 0                            J.K. Rowling/Mary GrandPrÌ©           4.57
# ...

# %%
df.shape
# Out:
# (11127, 12)

# %%
df.describe()
# Out:
#              bookID  ratings_count  text_reviews_count
# count  11127.000000   1.112700e+04        11127.000000
# mean   21310.938887   1.793647e+04          541.859531
# std    13093.358023   1.124794e+05         2576.175586
# min        1.000000   0.000000e+00            0.000000
# 25%    10287.000000   1.040000e+02            9.000000
# 50%    20287.000000   7.450000e+02           46.000000
# 75%    32104.500000   4.993500e+03          237.500000
# max    45641.000000   4.597666e+06        94265.000000

# %%
df.drop(["isbn13"],axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [30], in <cell line: 1>()
# ----> 1 df.drop(["isbn13"],axis=1,inplace=True)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
#    4815     errors: str = "raise",
#    4816 ):
# ...

# %%
df
# Out:
#        bookID                                              title  \
# 0           1  Harry Potter and the Half-Blood Prince (Harry ...
# 1           2  Harry Potter and the Order of the Phoenix (Har...
# 2           4  Harry Potter and the Chamber of Secrets (Harry...
# 3           5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4           8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
# ...       ...                                                ...
# 11122   45631   Expelled from Eden: A William T. Vollmann Reader
# 11123   45633                        You Bright and Risen Angels
# 11124   45634                    The Ice-Shirt (Seven Dreams #1)
# 11125   45639                                        Poor People
# 11126   45641                        Las aventuras de Tom Sawyer
#
#                                                  authors average_rating  \
# 0                            J.K. Rowling/Mary GrandPrÌ©           4.57
# ...

# %% [markdown]
# RENAME COLUMNS

# %%
df.columns
# Out:
# Index(['bookID', 'title', 'authors', 'average_rating', 'isbn', 'language_code',
#        'num_pages', 'ratings_count', 'text_reviews_count', 'publication_date',
#        'publisher'],
#       dtype='object')

# %%
df.columns = ["BookID","Title","Author","Rating","ISBN","Lang_Code","Pages","Rating_count","Reviews","DOP","Publisher"]

# %%
df
# Out:
#        BookID                                              Title  \
# 0           1  Harry Potter and the Half-Blood Prince (Harry ...
# 1           2  Harry Potter and the Order of the Phoenix (Har...
# 2           4  Harry Potter and the Chamber of Secrets (Harry...
# 3           5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4           8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
# ...       ...                                                ...
# 11122   45631   Expelled from Eden: A William T. Vollmann Reader
# 11123   45633                        You Bright and Risen Angels
# 11124   45634                    The Ice-Shirt (Seven Dreams #1)
# 11125   45639                                        Poor People
# 11126   45641                        Las aventuras de Tom Sawyer
#
#                                                   Author Rating        ISBN  \
# 0                            J.K. Rowling/Mary GrandPrÌ©   4.57   439785960
# ...

# %%
original_df = df
copy_df = df
original_df
# Out:
#        BookID                                              Title  \
# 0           1  Harry Potter and the Half-Blood Prince (Harry ...
# 1           2  Harry Potter and the Order of the Phoenix (Har...
# 2           4  Harry Potter and the Chamber of Secrets (Harry...
# 3           5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4           8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
# ...       ...                                                ...
# 11122   45631   Expelled from Eden: A William T. Vollmann Reader
# 11123   45633                        You Bright and Risen Angels
# 11124   45634                    The Ice-Shirt (Seven Dreams #1)
# 11125   45639                                        Poor People
# 11126   45641                        Las aventuras de Tom Sawyer
#
#                                                   Author Rating        ISBN  \
# 0                            J.K. Rowling/Mary GrandPrÌ©   4.57   439785960
# ...

# %%
copy_df.dtypes
# Out:
# BookID           int64
# Title           object
# Author          object
# Rating          object
# ISBN            object
# Lang_Code       object
# Pages           object
# Rating_count     int64
# Reviews          int64
# DOP             object
# Publisher       object
# dtype: object

# %%
l1 = ["enm","en-GB","en-US"]
for i in range (len(l1)):
    if copy_df[copy_df["Lang_Code"] == l1[i]]:
       copy_df["Lang_Code"] = "eng"
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [68], in <cell line: 2>()
#       1 l1 = ["enm","en-GB","en-US"]
#       2 for i in range (len(l1)):
# ----> 3     if copy_df[copy_df["Lang_Code"] == l1[i]]:
#       4        copy_df["Lang_Code"] = "eng"
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:1527, in NDFrame.__nonzero__(self)
#    1525 @final
#    1526 def __nonzero__(self):
# -> 1527     raise ValueError(
#    1528         f"The truth value of a {type(self).__name__} is ambiguous. "
#    1529         "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1530     )
#
# ValueError: The truth value of a DataFrame is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %% [markdown]
# MERGING SIMILAR DATA

# %%
copy_df["Lang_Code"].replace({"enm":"eng"},inplace=True)

# %%
copy_df["Lang_Code"].unique()
# Out:
# array(['eng', 'en-US', 'fre', 'spa', 'en-GB', 'mul', 'grc', 'en-CA',
#        'ger', 'jpn', 'ara', 'nl', 'zho', 'lat', 'por', 'srp', 'ita',
#        9780000000000, 'rus', 'msa', 'glg', 'wel', 'swe', 'nor', 'tur',
#        'gla', 'ale'], dtype=object)

# %%
copy_df["Lang_Code"].replace({"en-GB":"eng"},inplace=True)
copy_df["Lang_Code"].replace({"en-US":"eng"},inplace=True)
copy_df["Lang_Code"].unique()
# Out:
# array(['eng', 'fre', 'spa', 'mul', 'grc', 'en-CA', 'ger', 'jpn', 'ara',
#        'nl', 'zho', 'lat', 'por', 'srp', 'ita', 9780000000000, 'rus',
#        'msa', 'glg', 'wel', 'swe', 'nor', 'tur', 'gla', 'ale'],
#       dtype=object)

# %%
copy_df["Lang_Code"].replace({"en-CA":"eng"},inplace=True)
copy_df["Lang_Code"].unique()
# Out:
# array(['eng', 'fre', 'spa', 'mul', 'grc', 'ger', 'jpn', 'ara', 'nl',
#        'zho', 'lat', 'por', 'srp', 'ita', 9780000000000, 'rus', 'msa',
#        'glg', 'wel', 'swe', 'nor', 'tur', 'gla', 'ale'], dtype=object)

# %%
copy_df = copy_df.sort_values(by="Author", ascending=True)

# %%
copy_df
# Out:
#        BookID                                              Title  \
# 8040    30855                               A Woman in Jerusalem
# 7172    27503                                The Liberated Bride
# 4954    17883  Notes from Underground & A Confession (Everyma...
# 10114   40880  Jack Vance: Critical Appreciations and a Bibli...
# 7303    28116  The Know-It-All: One Man's Humble Quest to Bec...
# ...       ...                                                ...
# 7386    28419                                       La DÌ©bÌ¢cle
# 7382    28413                               The Ladies' Paradise
# 7380    28409                                    The Masterpiece
# 7378    28407                                           Germinal
# 1246     4314            Monsieur Ibrahim et les fleurs du Coran
#
#                                                   Author Rating        ISBN  \
# 8040                         A.B. Yehoshua/Hillel Halkin   3.43   151012261
# ...

# %% [markdown]
# MAPPING DATA

# %%
copy_df['Rating'] = pd.to_numeric(copy_df['Rating'], errors='coerce').astype(float)

# %%
copy_df.dtypes
# Out:
# BookID            int64
# Title            object
# Author           object
# Rating          float64
# ISBN             object
# Lang_Code        object
# Pages            object
# Rating_count      int64
# Reviews           int64
# DOP              object
# Publisher        object
# dtype: object

# %%
copy_df.loc[(copy_df['Rating'] >= 4.0) & (copy_df['Rating'] <= 4.50), 'Rating'] = 4

# %%
copy_df
# Out:
#        BookID                                              Title  \
# 8040    30855                               A Woman in Jerusalem
# 7172    27503                                The Liberated Bride
# 4954    17883  Notes from Underground & A Confession (Everyma...
# 10114   40880  Jack Vance: Critical Appreciations and a Bibli...
# 7303    28116  The Know-It-All: One Man's Humble Quest to Bec...
# ...       ...                                                ...
# 7386    28419                                       La DÌ©bÌ¢cle
# 7382    28413                               The Ladies' Paradise
# 7380    28409                                    The Masterpiece
# 7378    28407                                           Germinal
# 1246     4314            Monsieur Ibrahim et les fleurs du Coran
#
#                                                   Author  Rating        ISBN  \
# 8040                         A.B. Yehoshua/Hillel Halkin    3.43   151012261
# ...

# %%
copy_df.loc[(copy_df['Rating'] >= 4.51),'Rating'] = 5
copy_df.loc[(copy_df['Rating'] >= 3.51) & (copy_df['Rating'] < 4.00), 'Rating'] = 4
copy_df.loc[(copy_df['Rating'] >= 2.51) & (copy_df['Rating'] <= 3.50), 'Rating'] = 3
copy_df.loc[(copy_df['Rating'] >= 1.51) & (copy_df['Rating'] <= 2.50), 'Rating'] = 2
copy_df.loc[(copy_df['Rating'] <= 1.50), 'Rating'] = 1

# %%
copy_df
# Out:
#        BookID                                              Title  \
# 8040    30855                               A Woman in Jerusalem
# 7172    27503                                The Liberated Bride
# 4954    17883  Notes from Underground & A Confession (Everyma...
# 10114   40880  Jack Vance: Critical Appreciations and a Bibli...
# 7303    28116  The Know-It-All: One Man's Humble Quest to Bec...
# ...       ...                                                ...
# 7386    28419                                       La DÌ©bÌ¢cle
# 7382    28413                               The Ladies' Paradise
# 7380    28409                                    The Masterpiece
# 7378    28407                                           Germinal
# 1246     4314            Monsieur Ibrahim et les fleurs du Coran
#
#                                                   Author  Rating        ISBN  \
# 8040                         A.B. Yehoshua/Hillel Halkin     3.0   151012261
# ...

# %%
copy_df["Rating"].unique()
# Out:
# array([ 3.,  4.,  5.,  1., nan,  2.])

# %%
copy_df["Rating"].isnull().sum()
# Out:
# 3

# %%
index = df[df['Rating'].isnull()].index
index
# Out:
# Int64Index([], dtype='int64')

# %%
copy_df.loc[(copy_df['Rating'].isnull()), 'Rating'] = 0

# %%
copy_df["Rating"].unique()
# Out:
# array([3., 4., 5., 1., 0., 2.])

# %%
copy_df = copy_df.sort_values(by=['Author', 'Rating'], ascending=[True, False])
copy_df
# Out:
#        BookID                                              Title  \
# 7172    27503                                The Liberated Bride
# 8040    30855                               A Woman in Jerusalem
# 4954    17883  Notes from Underground & A Confession (Everyma...
# 10114   40880  Jack Vance: Critical Appreciations and a Bibli...
# 7303    28116  The Know-It-All: One Man's Humble Quest to Bec...
# ...       ...                                                ...
# 7386    28419                                       La DÌ©bÌ¢cle
# 7382    28413                               The Ladies' Paradise
# 7378    28407                                           Germinal
# 7380    28409                                    The Masterpiece
# 1246     4314            Monsieur Ibrahim et les fleurs du Coran
#
#                                                   Author  Rating        ISBN  \
# 7172                         A.B. Yehoshua/Hillel Halkin     4.0   156030160
# ...

# %%
copy_df['BookID'].duplicated().sum()
# Out:
# 0

# %%
copy_df['ISBN'].duplicated().sum()
# Out:
# 0

# %%
df['Title'].duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 11122    False
# 11123    False
# 11124    False
# 11125    False
# 11126    False
# Name: Title, Length: 11127, dtype: bool

# %%
copy_df[copy_df['Title'].duplicated()==True]
# Out:
#       BookID                                     Title  \
# 7262   27861     Data Structures and Algorithms in C++
# 7216   27669                           Bury the Chains
# 474     1525                              The Oresteia
# 5728   21348                            Aesop's Fables
# 4535   16331  Murder at the Vicarage (Miss Marple  #1)
# ...      ...                                       ...
# 1098    3711                               White Teeth
# 1097    3710                         The Autograph Man
# 36        61                            The Changeling
# 9569   38068                      The Complete Stories
# 7070   26973              Their Eyes Were Watching God
#
#                                                  Author  Rating        ISBN  \
# 7262                                       Adam Drozdek     4.0   534375979
# 7216                                    Adam Hochschild     4.0   333904915
# ...

# %%
copy_df["Publisher"].replace({"Scholastic":"Scholastic Inc."},inplace=True)

# %% [markdown]
# DATA COMPARISON

# %%
original_df
# Out:
#        BookID                                              Title  \
# 0           1  Harry Potter and the Half-Blood Prince (Harry ...
# 1           2  Harry Potter and the Order of the Phoenix (Har...
# 2           4  Harry Potter and the Chamber of Secrets (Harry...
# 3           5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4           8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
# ...       ...                                                ...
# 11122   45631   Expelled from Eden: A William T. Vollmann Reader
# 11123   45633                        You Bright and Risen Angels
# 11124   45634                    The Ice-Shirt (Seven Dreams #1)
# 11125   45639                                        Poor People
# 11126   45641                        Las aventuras de Tom Sawyer
#
#                                                   Author Rating        ISBN  \
# 0                            J.K. Rowling/Mary GrandPrÌ©   4.57   439785960
# ...

# %%
copy_df
# Out:
#        BookID                                              Title  \
# 7172    27503                                The Liberated Bride
# 8040    30855                               A Woman in Jerusalem
# 4954    17883  Notes from Underground & A Confession (Everyma...
# 10114   40880  Jack Vance: Critical Appreciations and a Bibli...
# 7303    28116  The Know-It-All: One Man's Humble Quest to Bec...
# ...       ...                                                ...
# 7386    28419                                       La DÌ©bÌ¢cle
# 7382    28413                               The Ladies' Paradise
# 7378    28407                                           Germinal
# 7380    28409                                    The Masterpiece
# 1246     4314            Monsieur Ibrahim et les fleurs du Coran
#
#                                                   Author  Rating        ISBN  \
# 7172                         A.B. Yehoshua/Hillel Halkin     4.0   156030160
# ...

# %% [markdown]
# DATA VISUALIZATION

# %%
value_counts = copy_df['Rating'].value_counts()
value_counts.plot(kind="bar",edgecolor="black")
plt.title("Rating Graph")
plt.xlabel("Ratings")
plt.ylabel("Count")
plt.show()

# %%
copy_df["Rating"].unique()
# Out:
# array([4., 3., 5., 1., 0., 2.])

# %%
value_counts = copy_df['Rating'].value_counts()
colors = ["lime","yellow","green","blue","orange","red"]
plt.pie(value_counts,colors=colors,radius=2)
plt.legend(value_counts.index, title='Ratings')
plt.show()

# %%
Book_List = copy_df[["BookID","Title","Author","Publisher"]].copy()
Book_List
# Out:
#        BookID                                              Title  \
# 7172    27503                                The Liberated Bride
# 8040    30855                               A Woman in Jerusalem
# 4954    17883  Notes from Underground & A Confession (Everyma...
# 10114   40880  Jack Vance: Critical Appreciations and a Bibli...
# 7303    28116  The Know-It-All: One Man's Humble Quest to Bec...
# ...       ...                                                ...
# 7386    28419                                       La DÌ©bÌ¢cle
# 7382    28413                               The Ladies' Paradise
# 7378    28407                                           Germinal
# 7380    28409                                    The Masterpiece
# 1246     4314            Monsieur Ibrahim et les fleurs du Coran
#
#                                                   Author  \
# 7172                         A.B. Yehoshua/Hillel Halkin
# 8040                         A.B. Yehoshua/Hillel Halkin
# ...

# %% [markdown]
# BOOK SUGGESTING SYSTEM

# %%
from sklearn.model_selection import train_test_split as tts
from sklearn.neighbors import KNeighborsClassifier as knn
from sklearn.metrics import accuracy_score as acc

# %%
data = copy_df

# %%
x = data[['Author', 'Lang_Code', 'Pages', 'Rating_count', 'Reviews', 'DOP']]
y = data['Rating']

# %%
x1,x2,y1,y2 = tts(x,y,test_size=0.25)

# %%
model = knn()
model.fit(x1,y1)
pred = model.predict(x2)

# %%
ac = acc(pred,y2)
print("Accuracy:",ac)
print(pred)
